# %% [markdown]
# # Experimento 11 (protocol analysis/Ju01)

# %% [markdown]
# Investigar a estrutura biomecânica da marcha em condição Ju01 utilizando K-Means sem redução dimensional.

# %% [markdown]
# A condição Ju01 representa a caminhada em ritmo confortável sem estímulo auditivo rítmico.

# %% [markdown]
# # 1. Importando as bibliotecas

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from sklearn.preprocessing import StandardScaler

from sklearn.cluster import KMeans

from sklearn.metrics import (
    silhouette_score,
    davies_bouldin_score,
    calinski_harabasz_score
)

from sklearn.decomposition import PCA

from google.colab import drive

# %% [markdown]
# # 2. Montando o Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 3. Carregando o Dataset Baseline

# %%
BASE_PATH = Path('/content/drive/MyDrive/results')

ju_file = BASE_PATH / 'ju_baseline_features.csv'

ju_df = pd.read_csv(ju_file)

ju_df.head()
# Out:
#   dataset patient_id  mean_total_L  mean_total_R  std_total_L  std_total_R  \
# 0      Ju  JuCo06_01    491.034501    458.574755   408.370356   387.052169
# 1      Ju  JuPt28_04    463.802448    441.058882   402.657635   390.279068
# 2      Ju  JuPt28_05    461.044277    439.617162   404.446082   392.266889
# 3      Ju  JuCo19_01    397.458941    384.621782   351.571417   335.652774
# 4      Ju  JuPt03_05    447.612376    449.400087   376.883198   395.509597
#
#    cv_total_L  cv_total_R  assimetria_mean  assimetria_abs  peak_force_L  \
# 0    0.831653    0.844033        32.459747       32.459747       1003.64
# 1    0.868166    0.884868        22.743566       22.743566       1014.09
# 2    0.877239    0.892292        21.427115       21.427115       1018.93
# 3    0.884548    0.872683        12.837160       12.837160        944.13
# 4    0.841986    0.880083        -1.787712        1.787712       1045.11
#
#    peak_force_R
# 0       1011.23
# 1       1015.41
# 2       1013.32
# 3        906.73
# 4       1016.07

# %%
ju_df.shape
# Out:
# (129, 12)

# %%
ju_df.info()
ju_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dataset          129 non-null    object
#  1   patient_id       129 non-null    object
#  2   mean_total_L     129 non-null    float64
#  3   mean_total_R     129 non-null    float64
#  4   std_total_L      129 non-null    float64
#  5   std_total_R      129 non-null    float64
#  6   cv_total_L       129 non-null    float64
#  7   cv_total_R       129 non-null    float64
#  8   assimetria_mean  129 non-null    float64
#  9   assimetria_abs   129 non-null    float64
#  10  peak_force_L     129 non-null    float64
#  11  peak_force_R     129 non-null    float64
# dtypes: float64(10), object(2)
# memory usage: 12.2+ KB
#        mean_total_L  mean_total_R  std_total_L  std_total_R  cv_total_L  \
# count    129.000000    129.000000   129.000000   129.000000  129.000000
# mean     455.051828    457.171072   393.188616   395.117905    0.865350
# std       71.029879     67.360979    59.454903    57.136178    0.030755
# min      297.722340    280.285646   253.381604   251.828916    0.811314
# 25%      409.533942    419.375957   356.771428   368.300552    0.840375
# 50%      461.467481    458.574755   392.219574   394.652427    0.864917
# 75%      493.580845    502.505420   436.113674   438.293948    0.886674
# max      687.630032    702.366501   612.168131   634.996815    0.938781
#
#        cv_total_R  assimetria_mean  assimetria_abs  peak_force_L  peak_force_R
# count  129.000000       129.000000      129.000000    129.000000    129.000000
# mean     0.865192        -2.119244       27.710268   1081.392093   1067.957597
# std      0.027199        37.795212       25.673848    167.330017    157.825427
# min      0.789306      -104.968020        0.904334    679.360000    662.200000
# 25%      0.849707       -17.495787        9.383295    993.410000    970.420000
# 50%      0.867851        -1.787712       19.450620   1054.020000   1024.100000
# 75%      0.883101        20.686953       38.433776   1208.680000   1195.370000
# max      0.929556        86.617580      104.968020   1816.540000   1866.590000

# %% [markdown]
# ### Filtrando somente a condição Ju01

# %%
ju01_df = ju_df[
    ju_df['patient_id'].str.endswith('_01')
]

ju01_df.head()
# Out:
#    dataset patient_id  mean_total_L  mean_total_R  std_total_L  std_total_R  \
# 0       Ju  JuCo06_01    491.034501    458.574755   408.370356   387.052169
# 3       Ju  JuCo19_01    397.458941    384.621782   351.571417   335.652774
# 5       Ju  JuPt24_01    429.822427    450.173481   364.381078   399.206651
# 6       Ju  JuPt03_01    409.533942    431.758334   337.354056   372.986560
# 12      Ju  JuCo04_01    412.262392    414.693361   356.771428   358.328755
#
#     cv_total_L  cv_total_R  assimetria_mean  assimetria_abs  peak_force_L  \
# 0     0.831653    0.844033        32.459747       32.459747       1003.64
# 3     0.884548    0.872683        12.837160       12.837160        944.13
# 5     0.847748    0.886784       -20.351054       20.351054        981.09
# 6     0.823751    0.863878       -22.224392       22.224392        870.76
# 12    0.865399    0.864081        -2.430969        2.430969        944.90
#
#     peak_force_R
# 0        1011.23
# 3         906.73
# 5        1039.61
# 6         976.47
# 12        925.32

# %% [markdown]
# Verificando o subconjunto

# %%
ju01_df.shape
# Out:
# (54, 12)

# %%
ju01_df['patient_id'].head(5)
# Out:
# 0     JuCo06_01
# 3     JuCo19_01
# 5     JuPt24_01
# 6     JuPt03_01
# 12    JuCo04_01
# Name: patient_id, dtype: object

# %% [markdown]
# ### Estatísticas descritivas sobre o subconjunto

# %%
ju01_df.describe()
# Out:
#        mean_total_L  mean_total_R  std_total_L  std_total_R  cv_total_L  \
# count     54.000000     54.000000    54.000000    54.000000   54.000000
# mean     440.515148    440.074468   381.906073   380.966568    0.867107
# std       73.685330     68.696455    64.855679    60.047511    0.028576
# min      297.722340    280.285646   256.607368   251.828916    0.811314
# 25%      387.572000    402.376840   339.083110   350.663902    0.851773
# 50%      434.388724    445.231311   379.891346   376.486268    0.864481
# 75%      484.784069    476.790385   416.719434   413.817235    0.884860
# max      687.630032    702.366501   612.168131   634.996815    0.938781
#
#        cv_total_R  assimetria_mean  assimetria_abs  peak_force_L  peak_force_R
# count   54.000000        54.000000       54.000000     54.000000     54.000000
# mean     0.866552         0.440681       25.049085   1047.709259   1028.679259
# std      0.031643        32.704557       20.748264    201.228025    182.089197
# min      0.789306       -65.194390        2.430969    679.360000    662.200000
# 25%      0.843523       -20.007362       10.005347    916.987500    927.382500
# 50%      0.866832        -4.499791       18.970361   1007.820000    992.640000
# 75%      0.886422        17.200035       37.720475   1174.662500   1129.150000
# max      0.929556        86.617580       86.617580   1816.540000   1866.590000

# %% [markdown]
# # 4. Defininção das features

# %% [markdown]
# Removendo colunas não utilizadas no clustering

# %%
feature_cols = [
    'mean_total_L',
    'mean_total_R',

    'std_total_L',
    'std_total_R',

    'cv_total_L',
    'cv_total_R',

    'assimetria_mean',
    'assimetria_abs',

    'peak_force_L',
    'peak_force_R'
]

X = ju01_df[feature_cols]

# %% [markdown]
# # 5. Normalização dos dados

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # 6. Escolha do número de clusters

# %% [markdown]
# ## Elbow Method

# %%
inertia = []

k_values = range(2, 7)

for k in k_values:

    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    kmeans.fit(X_scaled)

    inertia.append(kmeans.inertia_)

# %% [markdown]
# Visualizando o Elbow Method

# %%
plt.figure(figsize=(8,5))

plt.plot(k_values, inertia, marker='o')

plt.title('Elbow Method - Ju01')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Inertia')

plt.show()

# %% [markdown]
# # 7. Avaliação com Silhouette Score

# %%
silhouette_scores = []

for k in k_values:

    kmeans = KMeans(
        n_clusters=k,
        random_state=42,
        n_init=10
    )

    labels = kmeans.fit_predict(X_scaled)

    score = silhouette_score(
        X_scaled,
        labels
    )

    silhouette_scores.append(score)

    print(f'k={k} | Silhouette Score: {score:.4f}')
# Out:
# k=2 | Silhouette Score: 0.3094
# k=3 | Silhouette Score: 0.2057
# k=4 | Silhouette Score: 0.2374
# k=5 | Silhouette Score: 0.2402
# k=6 | Silhouette Score: 0.2464

# %% [markdown]
# Vizualização com o Silhouette Score

# %%
plt.figure(figsize=(8,5))

plt.plot(
    k_values,
    silhouette_scores,
    marker='o'
)

plt.title('Silhouette Score')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Score')

plt.show()

# %%
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=clusters
)

plt.title('Clusters K-Means - Ju01')
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.colorbar(scatter)

plt.show()

# %% [markdown]
# # 8. Treinamento final com o K-Means

# %%
kmeans = KMeans(
    n_clusters=2,
    random_state=42,
    n_init=10
)

clusters = kmeans.fit_predict(X_scaled)

# %% [markdown]
# Adicionando clusters ao dataframe

# %%
ju01_df['cluster'] = clusters

ju01_df.head()
# Out:
# /tmp/ipykernel_47542/2244782533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ju01_df['cluster'] = clusters
#    dataset patient_id  mean_total_L  mean_total_R  std_total_L  std_total_R  \
# 0       Ju  JuCo06_01    491.034501    458.574755   408.370356   387.052169
# 3       Ju  JuCo19_01    397.458941    384.621782   351.571417   335.652774
# 5       Ju  JuPt24_01    429.822427    450.173481   364.381078   399.206651
# 6       Ju  JuPt03_01    409.533942    431.758334   337.354056   372.986560
# 12      Ju  JuCo04_01    412.262392    414.693361   356.771428   358.328755
#
#     cv_total_L  cv_total_R  assimetria_mean  assimetria_abs  peak_force_L  \
# 0     0.831653    0.844033        32.459747       32.459747       1003.64
# 3     0.884548    0.872683        12.837160       12.837160        944.13
# 5     0.847748    0.886784       -20.351054       20.351054        981.09
# 6     0.823751    0.863878       -22.224392       22.224392        870.76
# 12    0.865399    0.864081        -2.430969        2.430969        944.90
#
#     peak_force_R  cluster
# 0        1011.23        0
# 3         906.73        0
# 5        1039.61        0
# 6         976.47        0
# 12        925.32        0

# %% [markdown]
# # 9. Métricas Internas

# %%
silhouette = silhouette_score(
    X_scaled,
    clusters
)

davies = davies_bouldin_score(
    X_scaled,
    clusters
)

calinski = calinski_harabasz_score(
    X_scaled,
    clusters
)

print(f'Silhouette Score: {silhouette:.4f}')
print(f'Davies-Bouldin Index: {davies:.4f}')
print(f'Calinski-Harabasz Score: {calinski:.4f}')
# Out:
# Silhouette Score: 0.3094
# Davies-Bouldin Index: 1.2525
# Calinski-Harabasz Score: 25.6906

# %% [markdown]
# # 10. Visualização dos Clusters

# %% [markdown]
# PCA somente usado para visualização

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=clusters
)

plt.title('Clusters K-Means - Ju01')
plt.xlabel('PC1')
plt.ylabel('PC2')

plt.colorbar(scatter)

plt.show()

# %% [markdown]
# # 11. HeatMap dos centroídes

# %%
centroids = pd.DataFrame(
    kmeans.cluster_centers_,
    columns=feature_cols
)

# %%
plt.figure(figsize=(12,6))

sns.heatmap(
    centroids,
    annot=True,
    cmap='coolwarm'
)

plt.title('Centroides dos Clusters - Ga01')

plt.show()

# %% [markdown]
# # 12. Distribuição dos Clusters

# %%
ju01_df['cluster'].value_counts()
# Out:
# cluster
# 0    37
# 1    17
# Name: count, dtype: int64

# %% [markdown]
# # 13. Composição por Grupo Clínico

# %% [markdown]
# Parkinson vs Controle

# %%
ju01_df['grupo'] = np.where(
    ju01_df['patient_id'].str.contains('Pt'),
    'Parkinson',
    'Controle'
)
# Out:
# /tmp/ipykernel_47542/347758822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ju01_df['grupo'] = np.where(

# %%
pd.crosstab(
    ju01_df['cluster'],
    ju01_df['grupo']
)
# Out:
# grupo    Controle  Parkinson
# cluster
# 0              17         20
# 1               8          9

# %% [markdown]
# # 14. Média das features por cluster

# %%
ju01_df.groupby(
    'cluster'
)[feature_cols].mean()
# Out:
#          mean_total_L  mean_total_R  std_total_L  std_total_R  cv_total_L  \
# cluster
# 0          403.849442    410.884082   348.987277   352.979892    0.864684
# 1          520.316980    503.606484   453.552866   441.878744    0.872382
#
#          cv_total_R  assimetria_mean  assimetria_abs  peak_force_L  \
# cluster
# 0          0.861399        -7.034640       22.305562    947.855135
# 1          0.877766        16.710496       31.020283   1265.038824
#
#          peak_force_R
# cluster
# 0          939.750811
# 1         1222.229412
